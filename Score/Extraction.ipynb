# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.iplt20.com/teams" 
data = requests.get(url) 
soup = BeautifulSoup(data.text,'html.parser') 

#Extract the URLs of the individual teams
teams = soup.select("div.vn-teamsInner")[0]
links = teams.find_all('a')
teams_urls = [l.get('href') for l in links]

#Getting data from individual page
data_team = requests.get(teams_urls[0])
soup_1 = BeautifulSoup(data_team.text)
soup_1
#csk = soup.select("div.filter-has")[0]
#csk
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title data-page-title="Chennai Super Kings | CSK 2025 Squad &amp; Overview | IPLT20" id="page_title">Chennai Super Kings | CSK 2025 Squad &amp; Overview | IPLT20</title>
# <link href="https://www.iplt20.com/teams/chennai-super-kings" rel="canonical"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <!-- <meta name="viewport" content="width=device-width, user-scalable=no" /> -->
# <meta content="gtEw2Du3e0DYQyhOS4HfNtsNj3lS5AeUUt7Lk2We" name="csrf-token"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="#19398a" name="theme-color"/>
# <meta content="website" name="og:type"/>
# <meta content="https://www.iplt20.com/teams/chennai-super-kings" name="og:url"/>
# ...
